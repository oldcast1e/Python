# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#1
# 데이터
RING_TIP_TO_DIP_CLOSE = [
[82,87,85,73,72,72,88,90,92,85],
[78,84,84,85,82,84,87,83,84,79],
[75,79,85,89,89,90,85,96,86,83],
[77,80,95,103,105,114,87,105,92,97],
[90,82,92,113,104,102,95,98,95,103],
[98,95,91,101,99,97,96,97,98,100],
[96,94,91,95,96,96,96,76,97,97],
[94,91,90,84,91,91,95,75,91,97],
[82,70,86,60,80,66,81,49,82,75],
[70,64,53,49,68,49,72,49,67,58]
]

averages = [int(round(np.mean(column))) for column in RING_TIP_TO_DIP_CLOSE]

# 평균 그래프 그리기
plt.plot(averages, marker='o', linestyle='-')
plt.title('Average angle of RING_TIP_TO_DIP_CLOSE')
plt.xlabel('Index')
plt.ylabel('Average Value')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#2
import matplotlib.pyplot as plt

# 데이터
RING_DIP_TO_PIP_CLOSE = [
[75,82,82,77,77,79,80,80,82,80],
[79,81,80,81,78,81,77,78,82,79],
[78,81,80,87,78,81,82,81,83,82],
[77,92,81,92,76,86,91,87,103,82],
[89,107,106,109,94,98,102,114,111,96],
[103,102,107,104,109,102,99,107,105,108],
[103,96,101,100,101,97,96,98,97,107],
[101,91,95,97,95,94,94,96,94,99],
[96,90,93,95,93,94,94,96,93,98],
[97,90,91,95,93,93,92,95,92,94]
]

averages = [int(round(np.mean(column))) for column in RING_DIP_TO_PIP_CLOSE]

# 평균 그래프 그리기
plt.plot(averages, marker='o', linestyle='-')
plt.title('Average angle of RING_DIP_TO_PIP_CLOSE')
plt.xlabel('Index')
plt.ylabel('Average Value')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#3
import matplotlib.pyplot as plt

# 데이터
RING_PIP_TO_MCP_CLOSE = [
[77,76,72,79,70,77,79,76,82,78],
[79,77,77,76,78,77,78,77,81,78],
[79,78,78,76,77,79,77,76,78,80],
[81,80,76,78,76,78,79,79,81,77],
[81,83,78,79,80,82,78,78,85,86],
[81,87,83,79,82,86,81,80,91,86],
[83,88,86,83,87,93,81,85,96,91],
[88,89,91,90,94,97,90,88,99,100],
[91,92,92,94,100,101,91,95,110,110],
[99,94,97,98,103,103,93,100,110,113]
]

averages = [int(round(np.mean(column))) for column in RING_PIP_TO_MCP_CLOSE]

# 평균 그래프 그리기
plt.plot(averages, marker='o', linestyle='-')
plt.title('Average angle of RING_PIP_TO_MCP_CLOSE')
plt.xlabel('Index')
plt.ylabel('Average Value')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#4
import matplotlib.pyplot as plt

# 데이터
RING_MCP_TO_WRIST_CLOSE = [
[83,83,85,77,79,84,83,80,78,85],
[83,84,85,83,85,82,83,82,82,82],
[85,84,85,84,84,84,83,84,83,83],
[85,83,86,84,84,84,83,85,82,83],
[85,83,86,84,85,84,84,85,84,83],
[85,84,86,86,86,84,84,88,83,87],
[86,85,89,87,89,87,87,89,82,87],
[89,87,90,87,87,87,89,90,85,88],
[90,90,90,86,87,87,88,89,89,88],
[90,90,90,85,87,87,87,90,88,88]
]

averages = [int(round(np.mean(column))) for column in RING_MCP_TO_WRIST_CLOSE]

# 평균 그래프 그리기
plt.plot(averages, marker='o', linestyle='-')
plt.title('Average angle of RING_MCP_TO_WRIST_CLOSE')
plt.xlabel('Index')
plt.ylabel('Average Value')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()
