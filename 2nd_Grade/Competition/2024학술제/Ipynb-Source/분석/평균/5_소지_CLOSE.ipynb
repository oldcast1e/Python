# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#1
# 데이터
PINKY_TIP_TO_DIP_CLOSE = [
[73,57,95,84,98,83,86,96,78,69],
[58,67,60,56,56,63,56,59,56,56],
[75,75,84,71,71,81,76,67,67,72],
[100,87,119,83,78,136,130,82,79,97],
[116,115,134,112,109,111,128,114,102,107],
[104,116,108,106,113,102,107,108,122,106],
[106,113,104,108,101,90,92,97,111,102],
[102,97,104,108,101,90,92,97,111,102],
[97,39,81,92,69,55,49,38,57,41],
[89,35,73,74,64,52,49,72,32,29]
]

averages = [int(round(np.mean(column))) for column in PINKY_TIP_TO_DIP_CLOSE]

# 평균 그래프 그리기
plt.plot(averages, marker='o', linestyle='-')
plt.title('Average angle of PINKY_TIP_TO_DIP_CLOSE')
plt.xlabel('Index')
plt.ylabel('Average Value')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#2
import matplotlib.pyplot as plt

# 데이터
PINKY_DIP_TO_PIP_CLOSE = [
[60,65,70,79,65,89,75,90,87,90],
[55,58,65,53,56,64,59,55,56,57],
[64,70,73,63,71,70,70,76,71,71],
[76,103,90,71,90,78,90,83,80,91],
[93,129,119,94,113,98,114,124,108,132],
[124,115,120,113,141,127,145,125,129,127],
[130,105,106,109,116,125,122,114,114,110],
[113,102,106,105,106,109,105,107,108,102],
[102,99,102,104,101,103,102,105,103,101],
[100,99,101,102,99,99,99,99,101,101],
]

averages = [int(round(np.mean(column))) for column in PINKY_DIP_TO_PIP_CLOSE]

# 평균 그래프 그리기
plt.plot(averages, marker='o', linestyle='-')
plt.title('Average angle of PINKY_DIP_TO_PIP_CLOSE')
plt.xlabel('Index')
plt.ylabel('Average Value')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#3
import matplotlib.pyplot as plt

# 데이터
PINKY_PIP_TO_MCP_CLOSE = [
[65, 66, 62, 61, 61, 64, 62, 62, 62, 61],
[64, 68, 63, 64, 63, 64, 64, 64, 65, 64],
[66, 74, 67, 68, 65, 70, 68, 71, 70, 71],
[73, 80, 73, 75, 75, 79, 72, 74, 75, 75],
[76, 84, 76, 78, 77, 82, 79, 78, 78, 79],
[82, 87, 82, 83, 83, 87, 83, 81, 81, 82],
[84, 90, 85, 84, 88, 92, 94, 85, 88, 90],
[88, 94, 99, 90, 99, 96, 102, 92, 98, 100],
[95, 103, 110, 105, 105, 106, 101, 96, 103, 105],
[114, 111, 122, 109, 114, 104, 106, 105, 115, 113]
]

averages = [int(round(np.mean(column))) for column in PINKY_PIP_TO_MCP_CLOSE]

# 평균 그래프 그리기
plt.plot(averages, marker='o', linestyle='-')
plt.title('Average angle of PINKY_PIP_TO_MCP_CLOSE')
plt.xlabel('Index')
plt.ylabel('Average Value')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#4
import matplotlib.pyplot as plt

# 데이터
PINKY_MCP_TO_WRIST_CLOSE = [
[76, 78, 78, 78, 76, 76, 75, 77, 77, 74],
[78, 79, 78, 78, 75, 76, 75, 78, 76, 75],
[78, 79, 78, 77, 76, 73, 75, 77, 76, 73],
[78, 79, 77, 76, 74, 74, 74, 76, 75, 70],
[76, 80, 78, 77, 75, 75, 75, 78, 77, 72],
[79, 83, 78, 79, 78, 77, 78, 79, 79, 73],
[81, 78, 82, 80, 77, 72, 77, 76, 76, 74],
[78, 78, 80, 78, 76, 70, 74, 74, 75, 75],
[78, 78, 78, 75, 72, 70, 75, 76, 74, 77],
[79, 78, 80, 76, 74, 70, 75, 76, 79, 77]
]

averages = [int(round(np.mean(column))) for column in PINKY_MCP_TO_WRIST_CLOSE]

# 평균 그래프 그리기
plt.plot(averages, marker='o', linestyle='-')
plt.title('Average angle of PINKY_MCP_TO_WRIST_CLOSE')
plt.xlabel('Index')
plt.ylabel('Average Value')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()
