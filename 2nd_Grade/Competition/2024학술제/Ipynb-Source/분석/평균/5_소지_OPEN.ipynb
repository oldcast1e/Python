# %%
#1
import matplotlib.pyplot as plt

# 데이터
PINKY_DIP_TO_TIP_OPEN = [
    [69, 67, 70, 72, 67, 69, 73, 69, 70, 70],
    [68, 66, 70, 71, 65, 70, 72, 69, 70, 69],
    [68, 64, 70, 70, 66, 69, 72, 68, 70, 69],
    [69, 66, 71, 71, 68, 69, 72, 67, 70, 69],
    [70, 67, 69, 70, 67, 68, 73, 68, 70, 68],
    [69, 66, 69, 70, 68, 68, 73, 68, 71, 68],
    [69, 66, 68, 70, 67, 68, 73, 68, 70, 68],
    [70, 65, 68, 70, 68, 67, 74, 67, 71, 69],
    [69, 68, 70, 71, 68, 67, 73, 67, 71, 69],
    [69, 67, 70, 70, 70, 67, 72, 67, 70, 68]

]

# 각 열의 합을 구하기
sums_PINKY_DIP_TO_TIP_OPEN = [sum(column) for column in zip(*PINKY_DIP_TO_TIP_OPEN)]
averages_PINKY_DIP_TO_TIP_OPEN = [round(sum(row) / len(row)) for row in PINKY_DIP_TO_TIP_OPEN]
# 그래프 그리기
plt.plot(averages_PINKY_DIP_TO_TIP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of PINKY_DIP_TO_TIP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#2
import matplotlib.pyplot as plt

# 데이터
PINKY_PIP_TO_DIP_OPEN = [
    [64, 64, 63, 63, 66, 62, 65, 69, 68, 66],
    [65, 64, 64, 63, 67, 63, 64, 69, 67, 67],
    [64, 65, 63, 63, 65, 63, 63, 69, 66, 67],
    [64, 64, 65, 63, 67, 63, 64, 68, 66, 67],
    [64, 64, 66, 63, 66, 62, 63, 70, 65, 66],
    [65, 64, 65, 63, 66, 62, 63, 71, 66, 67],
    [65, 64, 66, 63, 66, 61, 63, 70, 66, 67],
    [65, 64, 64, 63, 66, 62, 64, 68, 67, 67],
    [64, 63, 65, 64, 65, 63, 63, 68, 66, 67],
    [65, 64, 65, 63, 65, 62, 64, 69, 65, 67]

]

# 각 열의 합을 구하기
sums_PINKY_PIP_TO_DIP_OPEN = [sum(column) for column in zip(*PINKY_PIP_TO_DIP_OPEN)]
averages_PINKY_PIP_TO_DIP_OPEN = [round(sum(row) / len(row)) for row in PINKY_PIP_TO_DIP_OPEN]
# 그래프 그리기
plt.plot(averages_PINKY_PIP_TO_DIP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of PINKY_PIP_TO_DIP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#3
import matplotlib.pyplot as plt

# 데이터
PINKY_MCP_TO_PIP_OPEN = [
    [64, 62, 64, 67, 65, 67, 65, 64, 64, 65],
    [64, 62, 63, 67, 66, 68, 65, 64, 63, 65],
    [64, 62, 64, 67, 66, 67, 65, 64, 63, 65],
    [65, 63, 64, 67, 66, 67, 65, 63, 63, 64],
    [64, 64, 66, 67, 65, 66, 65, 62, 63, 64],
    [64, 64, 65, 67, 65, 66, 65, 62, 64, 64],
    [64, 64, 65, 67, 65, 66, 64, 63, 63, 64],
    [63, 63, 66, 67, 65, 66, 65, 63, 62, 64],
    [63, 63, 66, 67, 65, 66, 63, 62, 62, 64],
    [64, 64, 66, 67, 65, 66, 64, 62, 63, 64]
]

# 각 열의 합을 구하기
sums_PINKY_MCP_TO_PIP_OPEN = [sum(column) for column in zip(*PINKY_MCP_TO_PIP_OPEN)]
averages_PINKY_MCP_TO_PIP_OPEN = [round(sum(row) / len(row)) for row in PINKY_MCP_TO_PIP_OPEN]
# 그래프 그리기
plt.plot(averages_PINKY_MCP_TO_PIP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of PINKY_MCP_TO_PIP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#4
import matplotlib.pyplot as plt

# 데이터
PINKY_WRIST_TO_MCP_OPEN = [
    [70, 73, 72, 71, 73, 74, 75, 73, 73, 72],
[71, 73, 72, 72, 73, 74, 74, 72, 73, 72],
[71, 73, 72, 72, 73, 74, 74, 72, 73, 72],
[71, 73, 72, 72, 73, 75, 74, 73, 72, 72],
[71, 74, 72, 72, 73, 74, 74, 73, 72, 72],
[71, 74, 72, 72, 73, 75, 74, 73, 72, 72],
[71, 74, 72, 72, 73, 74, 74, 73, 73, 71],
[71, 74, 72, 72, 73, 74, 74, 73, 72, 71],
[71, 74, 72, 72, 73, 74, 74, 73, 71, 71],
[71, 74, 72, 72, 74, 74, 74, 73, 71, 71]

]

# 각 열의 합을 구하기
sums_PINKY_WRIST_TO_MCP_OPEN = [sum(column) for column in zip(*PINKY_WRIST_TO_MCP_OPEN)]
averages_PINKY_WRIST_TO_MCP_OPEN = [round(sum(row) / len(row)) for row in PINKY_WRIST_TO_MCP_OPEN]
# 그래프 그리기
plt.plot(averages_PINKY_WRIST_TO_MCP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of PINKY_WRIST_TO_MCP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()
