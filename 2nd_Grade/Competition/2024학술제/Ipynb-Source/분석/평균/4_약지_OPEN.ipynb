# %%
#1
import matplotlib.pyplot as plt

# 데이터
RING_DIP_TO_TIP_OPEN = [
    [81, 81, 80, 80, 81, 81, 81, 81, 81, 81],
    [80, 80, 80, 80, 81, 81, 81, 81, 81, 81],
    [80, 80, 79, 81, 80, 81, 80, 81, 81, 81],
    [80, 81, 79, 80, 81, 81, 81, 81, 81, 81],
    [81, 81, 81, 81, 80, 81, 81, 81, 80, 81],
    [80, 81, 80, 80, 80, 81, 80, 81, 81, 81],
    [81, 81, 80, 80, 81, 81, 80, 81, 81, 81],
    [80, 80, 79, 80, 80, 82, 81, 81, 81, 81],
    [80, 81, 79, 80, 80, 82, 80, 81, 80, 81],
    [80, 80, 80, 80, 81, 81, 80, 81, 80, 81]

]

# 각 열의 합을 구하기
sums_RING_DIP_TO_TIP_OPEN = [sum(column) for column in zip(*RING_DIP_TO_TIP_OPEN)]
averages_RING_DIP_TO_TIP_OPEN = [round(sum(row) / len(row)) for row in RING_DIP_TO_TIP_OPEN]
# 그래프 그리기
plt.plot(averages_RING_DIP_TO_TIP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of RING_DIP_TO_TIP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#2
import matplotlib.pyplot as plt

# 데이터
RING_PIP_TO_DIP_OPEN = [
    [77, 78, 77, 78, 79, 78, 76, 81, 79, 78],
    [78, 78, 77, 78, 78, 78, 79, 81, 80, 78],
    [77, 78, 77, 78, 78, 78, 78, 81, 80, 79],
    [77, 78, 78, 78, 79, 78, 79, 80, 80, 78],
    [78, 78, 77, 79, 79, 78, 79, 81, 79, 78],
    [78, 78, 77, 78, 79, 79, 79, 80, 79, 78],
    [77, 77, 77, 78, 78, 78, 78, 81, 79, 78],
    [77, 77, 77, 78, 78, 78, 78, 80, 79, 79],
    [77, 77, 77, 78, 78, 78, 78, 80, 79, 78],
    [77, 77, 77, 78, 78, 78, 79, 80, 79, 78]

]

# 각 열의 합을 구하기
sums_RING_PIP_TO_DIP_OPEN = [sum(column) for column in zip(*RING_PIP_TO_DIP_OPEN)]
averages_RING_PIP_TO_DIP_OPEN = [round(sum(row) / len(row)) for row in RING_PIP_TO_DIP_OPEN]
# 그래프 그리기
plt.plot(averages_RING_PIP_TO_DIP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of RING_PIP_TO_DIP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#3
import matplotlib.pyplot as plt

# 데이터
RING_MCP_TO_PIP_OPEN = [
    [78, 78, 79, 80, 80, 80, 80, 79, 80, 78],
    [78, 78, 78, 80, 80, 80, 80, 79, 80, 78],
    [78, 78, 78, 80, 80, 81, 80, 79, 80, 79],
    [78, 78, 79, 80, 80, 81, 80, 79, 81, 79],
    [78, 78, 78, 79, 79, 81, 81, 79, 80, 79],
    [78, 78, 78, 80, 80, 80, 81, 79, 80, 78],
    [78, 78, 79, 80, 80, 81, 81, 79, 80, 78],
    [77, 78, 79, 80, 80, 81, 81, 78, 80, 78],
    [77, 78, 79, 80, 80, 81, 81, 78, 80, 78],
    [77, 78, 79, 80, 80, 81, 81, 78, 79, 78]
]

# 각 열의 합을 구하기
sums_RING_MCP_TO_PIP_OPEN = [sum(column) for column in zip(*RING_MCP_TO_PIP_OPEN)]
averages_RING_MCP_TO_PIP_OPEN = [round(sum(row) / len(row)) for row in RING_MCP_TO_PIP_OPEN]
# 그래프 그리기
plt.plot(averages_RING_MCP_TO_PIP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of RING_MCP_TO_PIP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#4
import matplotlib.pyplot as plt

# 데이터
RING_WRIST_TO_MCP_OPEN = [
    [84, 82, 84, 81, 79, 82, 83, 84, 82, 83],
    [84, 82, 83, 81, 80, 82, 83, 84, 82, 83],
    [84, 82, 83, 81, 81, 82, 82, 84, 82, 82],
    [83, 82, 83, 81, 81, 82, 82, 84, 82, 82],
    [84, 82, 83, 80, 81, 82, 82, 84, 82, 82],
    [84, 82, 83, 81, 81, 82, 82, 84, 82, 81],
    [84, 82, 83, 81, 80, 83, 82, 84, 82, 82],
    [84, 82, 83, 81, 80, 82, 84, 84, 82, 81],
    [84, 82, 83, 81, 80, 82, 84, 84, 82, 82],
    [83, 82, 83, 81, 80, 82, 84, 84, 82, 82]

]

# 각 열의 합을 구하기
sums_RING_WRIST_TO_MCP_OPEN = [sum(column) for column in zip(*RING_WRIST_TO_MCP_OPEN)]
averages_RING_WRIST_TO_MCP_OPEN = [round(sum(row) / len(row)) for row in RING_WRIST_TO_MCP_OPEN]
# 그래프 그리기
plt.plot(averages_RING_WRIST_TO_MCP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of RING_WRIST_TO_MCP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()
