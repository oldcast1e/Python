# %%
#1
import matplotlib.pyplot as plt

# 데이터
MIDDLE_DIP_TO_TIP_CLOSE = [
[91, 89, 89, 90, 91, 90, 92, 89, 90, 88],
[88, 88, 87, 88, 89, 89, 88, 90, 89, 90],
[83, 80, 88, 87, 94, 85, 84, 89, 88, 90],
[88, 92, 97, 96, 100, 93, 90, 100, 99, 106],
[87, 94, 88, 88, 89, 98, 88, 94, 94, 94],
[86, 88, 89, 86, 88, 87, 84, 88, 87, 88],
[61, 88, 80, 84, 80, 86, 69, 85, 83, 84],
[24, 68, 71, 23, 40, 85, 41, 80, 79, 72],
[30, 40, 24, 33, 47, 48, 20, 24, 66, 55],
[38, 32, 39, 19, 42, 18, 21, 5, 16, 52]
]

# 각 열의 합을 구하기
sums_MIDDLE_DIP_TO_TIP_CLOSE = [sum(column) for column in zip(*MIDDLE_DIP_TO_TIP_CLOSE)]
averages_MIDDLE_DIP_TO_TIP_CLOSE = [round(sum(row) / len(row)) for row in MIDDLE_DIP_TO_TIP_CLOSE]
# 그래프 그리기
plt.plot(averages_MIDDLE_DIP_TO_TIP_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of MIDDLE_DIP_TO_TIP_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#2
# 평균값 이상 발견 24.05.06
import matplotlib.pyplot as plt

# 데이터
MIDDLE_PIP_TO_DIP_CLOSE = [
[93, 93, 92, 93, 93, 94, 91, 90, 91, 90],
[90, 91, 88, 91, 90, 92, 89, 89, 88, 90],
[85, 88, 86, 89, 86, 86, 89, 88, 86, 86],
[86, 91, 88, 90, 84, 85, 94, 89, 85, 93],
[83, 102, 96, 90, 76, 91, 94, 97, 86, 96],
[81, 90, 89, 92, 80, 89, 87, 91, 88, 91],
[82, 89, 86, 88, 81, 87, 86, 90, 89, 90],
[86, 88, 86, 85, 82, 86, 87, 90, 88, 86],
[83, 85, 87, 85, 82, 85, 85, 89, 88, 85],
[84, 86, 87, 83, 80, 86, 87, 89, 86, 84]
]

# 각 열의 합을 구하기
sums_MIDDLE_PIP_TO_DIP_CLOSE = [sum(column) for column in zip(*MIDDLE_PIP_TO_DIP_CLOSE)]
averages_MIDDLE_PIP_TO_DIP_CLOSE = [round(sum(row) / len(row)) for row in MIDDLE_PIP_TO_DIP_CLOSE]
# 그래프 그리기
plt.plot(averages_MIDDLE_PIP_TO_DIP_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of MIDDLE_PIP_TO_DIP_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#1
import matplotlib.pyplot as plt

# 데이터
MIDDLE_WRIST_TO_MCP_CLOSE = [
[97, 96, 96, 96, 97, 96, 98, 94, 91, 94],
[97, 97, 96, 96, 97, 97, 98, 95, 94, 94],
[98, 97, 97, 96, 97, 98, 98, 94, 94, 95],
[97, 97, 96, 97, 97, 96, 98, 95, 94, 96],
[98, 97, 95, 97, 99, 97, 100, 95, 94, 96],
[97, 100, 98, 99, 100, 100, 98, 99, 97, 97],
[99, 100, 97, 98, 100, 99, 100, 98, 99, 96],
[98, 99, 97, 99, 100, 99, 100, 98, 97, 96],
[98, 98, 97, 100, 101, 99, 102, 96, 100, 95],
[97, 97, 97, 100, 99, 98, 100, 96, 100, 96]
]

# 각 열의 합을 구하기
sums_MIDDLE_WRIST_TO_MCP_CLOSE = [sum(column) for column in zip(*MIDDLE_WRIST_TO_MCP_CLOSE)]
averages_MIDDLE_WRIST_TO_MCP_CLOSE = [round(sum(row) / len(row)) for row in MIDDLE_WRIST_TO_MCP_CLOSE]
# 그래프 그리기
plt.plot(averages_MIDDLE_WRIST_TO_MCP_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of MIDDLE_WRIST_TO_MCP_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#4
import matplotlib.pyplot as plt

# 데이터
MIDDLE_MCP_TO_PIP_CLOSE = [
[90, 91, 92, 91, 93, 91, 93, 92, 94, 92],
[90, 90, 90, 91, 92, 91, 91, 91, 91, 91],
[88, 89, 90, 89, 91, 90, 91, 93, 91, 90],
[88, 91, 89, 89, 89, 92, 91, 93, 93, 92],
[88, 89, 87, 87, 90, 91, 90, 90, 89, 89],
[90, 90, 90, 89, 89, 92, 88, 89, 91, 88],
[92, 89, 90, 92, 94, 91, 90, 90, 91, 91],
[95, 86, 95, 93, 104, 94, 90, 89, 93, 92],
[97, 90, 104, 98, 107, 93, 93, 94, 95, 95],
[98, 92, 110, 103, 112, 103, 95, 93, 96 , 97]
]

# 각 열의 합을 구하기
sums_MIDDLE_MCP_TO_PIP_CLOSE = [sum(column) for column in zip(*MIDDLE_MCP_TO_PIP_CLOSE)]
averages_MIDDLE_MCP_TO_PIP_CLOSE = [round(sum(row) / len(row)) for row in MIDDLE_MCP_TO_PIP_CLOSE]
# 그래프 그리기
plt.plot(averages_MIDDLE_MCP_TO_PIP_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of MIDDLE_MCP_TO_PIP_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %% [markdown]
# WRIST [87, 87, 87, 88, 89, 86, 86, 86, 87, 89, 90]
# MIDDLE_FINGER_MCP [86, 87, 88, 91, 88, 86, 87, 83, 76, 55, 42]
# MIDDLE_FINGER_PIP [71, 84, 70, 55, 58, 68, 75, 82, 85, 86, 89]
# MIDDLE_FINGER_DIP [83, 81, 45, 69, 80, 83, 84, 88, 95, 108, 170]
#
# finger.WRIST,finger.MIDDLE_FINGER_MCP, finger.MIDDLE_FINGER_PIP, finger.MIDDLE_FINGER_DIP, finger.MIDDLE_FINGER_TIP
# User
# [87, 86, 71, 83]
# [87, 87, 84, 81]
# [87, 88, 70, 45]
# [88, 91, 55, 69]
# [89, 88, 58, 80]
# [86, 86, 68, 83]
# [86, 87, 75, 84]
# [86, 83, 82, 88]
# [87, 76, 85, 95]
# [89, 55, 86, 108]
# [90, 42, 89, 170]
#
# [87, 87, 87, 88, 89, 86, 86, 86, 87, 89, 90]
# [86, 87, 88, 91, 88, 86, 87, 83, 76, 55, 42]
# [71, 84, 70, 55, 58, 68, 75, 82, 85, 86, 89]
# [83, 81, 45, 69, 80, 83, 84, 88, 95, 108, 170]
#
# WRIST
