# %%
#1
import matplotlib.pyplot as plt

# 데이터
THUMB_MCP_TO_CMC_CLOSE = [
[120, 118, 115, 114, 116, 118, 115, 117, 119, 118, 119],
[119, 116, 115, 113, 112, 113, 118, 122, 124, 125, 122],
[120, 118, 116, 114, 115, 114, 117, 117, 123, 121, 122],
[119, 117, 114, 112, 115, 114, 118, 121, 126, 125, 125],
[125, 123, 119, 115, 116, 117, 120, 120, 122, 124, 122],
[119, 114, 112, 115, 116, 118, 123, 125, 124, 120, 119],
[122, 122, 120, 118, 116, 116, 117, 119, 124, 125, 125],
[121, 120, 117, 113, 113, 111, 113, 117, 123, 125, 122],
[120, 119, 117, 113, 110, 112, 115, 117, 122, 124, 123],
 [123, 118, 114, 112, 114, 122, 124, 123, 121, 119, 119]
]

# 각 열의 합을 구하기
sums_THUMB_MCP_TO_CMC_CLOSE = [sum(column) for column in zip(*THUMB_MCP_TO_CMC_CLOSE)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
# averages_THUMB_MCP_TO_CMC_CLOSE = [round(sum_value / len(THUMB_MCP_TO_CMC_CLOSE[0])) for sum_value in sums_THUMB_MCP_TO_CMC_CLOSE]
averages_THUMB_MCP_TO_CMC_CLOSE = [round(sum(row) / len(row)) for row in THUMB_MCP_TO_CMC_CLOSE]
# 그래프 그리기
plt.plot(averages_THUMB_MCP_TO_CMC_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_MCP_TO_CMC_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#2
import matplotlib.pyplot as plt

# 데이터
THUMB_IP_TO_MCP_CLOSE = [
[112, 108, 104, 104, 103, 106, 104, 98, 97, 86, 89],

[114, 108, 106, 102, 102, 100, 102, 100, 96, 90, 85],

[118, 114, 109, 106, 103, 104, 103, 103, 98, 89, 88],

[112, 109, 103, 99, 101, 101, 100, 98, 94, 87, 90],

[118, 115, 109, 104, 104, 104, 105, 102, 97, 89, 84],

[111, 105, 102, 102, 101, 102, 100, 93, 88, 80, 78],

[119, 115, 111, 108, 106, 103, 104, 102, 105, 101, 92],

[115, 111, 108, 104, 103, 99, 98, 102, 101, 93, 87],

[115, 110, 107, 104, 99, 101, 100, 99, 100, 95, 85],

 [117, 111, 107, 103, 105, 102, 101, 92, 87, 88, 87]
]

# 각 열의 합을 구하기
sums_THUMB_IP_TO_MCP_CLOSE = [sum(column) for column in zip(*THUMB_IP_TO_MCP_CLOSE)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
# averages_THUMB_IP_TO_MCP_CLOSE = [round(sum_value / len(THUMB_IP_TO_MCP_CLOSE[0])) for sum_value in sums_THUMB_IP_TO_MCP_CLOSE]
averages_THUMB_IP_TO_MCP_CLOSE = [round(sum(row) / len(row)) for row in THUMB_IP_TO_MCP_CLOSE]

# 그래프 그리기
plt.plot(averages_THUMB_IP_TO_MCP_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_IP_TO_MCP_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#3
import matplotlib.pyplot as plt

# 데이터
THUMB_MCP_TO_CMC_CLOSE = [
[120, 118, 115, 114, 116, 118, 115, 117, 119, 118, 119],

[119, 116, 115, 113, 112, 113, 118, 122, 124, 125, 122],

[120, 118, 116, 114, 115, 114, 117, 117, 123, 121, 122],

[119, 117, 114, 112, 115, 114, 118, 121, 126, 125, 125],

[125, 123, 119, 115, 116, 117, 120, 120, 122, 124, 122],

[119, 114, 112, 115, 116, 118, 123, 125, 124, 120, 119],

[122, 122, 120, 118, 116, 116, 117, 119, 124, 125, 125],

[121, 120, 117, 113, 113, 111, 113, 117, 123, 125, 122],

[120, 119, 117, 113, 110, 112, 115, 117, 122, 124, 123],

 [123, 118, 114, 112, 114, 122, 124, 123, 121, 119, 119]
]

# 각 열의 합을 구하기
sums_THUMB_MCP_TO_CMC_CLOSE = [sum(column) for column in zip(*THUMB_MCP_TO_CMC_CLOSE)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
#averages_THUMB_MCP_TO_CMC_CLOSE = [round(sum_value / len(THUMB_MCP_TO_CMC_CLOSE[0])) for sum_value in sums_THUMB_MCP_TO_CMC_CLOSE]
averages_THUMB_MCP_TO_CMC_CLOSE = [round(sum(row) / len(row)) for row in THUMB_MCP_TO_CMC_CLOSE]
# 그래프 그리기
plt.plot(averages_THUMB_MCP_TO_CMC_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_MCP_TO_CMC_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#4
import matplotlib.pyplot as plt

# 데이터
THUMB_CMC_TO_WRIST_CLOSE = [
[138, 137, 139, 138, 139, 137, 131, 131, 136, 136, 135],
[138, 137, 136, 137, 136, 132, 123, 125, 131, 134, 134],
[140, 140, 137, 140, 138, 135, 133, 130, 129, 133, 133],
[138, 137, 138, 136, 137, 131, 131, 124, 132, 137, 133],
[140, 137, 137, 134, 132, 129, 127, 134, 137, 139, 137],
[145, 143, 142, 141, 144, 134, 135, 127, 133, 138, 141],
[140, 140, 139, 139, 137, 139, 132, 133, 128, 130, 134],
[139, 138, 137, 136, 134, 130, 130, 132, 127, 134, 136],
[139, 137, 138, 136, 133, 132, 133, 126, 127, 128, 135],
 [139, 137, 135, 134, 131, 124, 132, 136, 134, 133, 133]
]

# 각 열의 합을 구하기
sums_THUMB_CMC_TO_WRIST_CLOSE = [sum(column) for column in zip(*THUMB_CMC_TO_WRIST_CLOSE)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
#averages_THUMB_CMC_TO_WRIST_CLOSE = [round(sum_value / len(THUMB_CMC_TO_WRIST_CLOSE[0])) for sum_value in sums_THUMB_CMC_TO_WRIST_CLOSE]
averages_THUMB_CMC_TO_WRIST_CLOSE = [round(sum(row) / len(row)) for row in THUMB_CMC_TO_WRIST_CLOSE]
# 그래프 그리기
plt.plot(averages_THUMB_CMC_TO_WRIST_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_CMC_TO_WRIST_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

averages = [round(sum(row) / len(row)) for row in THUMB_CMC_TO_WRIST_CLOSE]

print(averages)
# Out:
# [136, 133, 135, 134, 135, 138, 136, 134, 133, 133]

# %%
#1
import matplotlib.pyplot as plt
import numpy as np

# 데이터
THUMB_TIP_TO_IP_CLOSE = [
[116, 111, 108, 101, 92, 84, 80, 61, 54, 33, 39],
[123, 117, 112, 100, 88, 77, 63, 52, 48, 40, 37],
[129, 123, 119, 117, 101, 94, 78, 72, 53, 29, 37],
[121, 117, 113, 104, 92, 87, 62, 53, 46, 31, 39],
[127, 120, 113, 112, 101, 82, 67, 59, 48, 46, 35],
[119, 115, 110, 91, 73, 61, 57, 43, 41, 29, 31],
[130, 123, 118, 117, 111, 102, 81, 61, 56, 60, 45],
[125, 117, 116, 112, 108, 98, 76, 70, 62, 42, 33],
[127, 115, 112, 112, 102, 87, 77, 62, 54, 44, 37],
 [124, 117, 111, 103, 82, 60, 60, 49, 41, 46, 44]
 ]
THUMB_TIP_TO_IP_CLOSE_T = np.transpose(THUMB_TIP_TO_IP_CLOSE)

# 각 열의 합을 구하기
sums_THUMB_TIP_TO_IP_CLOSE_T = [sum(column) for column in zip(*THUMB_TIP_TO_IP_CLOSE_T)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
# averages_THUMB_TIP_TO_IP_CLOSE = [round(sum_value / len(THUMB_TIP_TO_IP_CLOSE[0])) for sum_value in sums_THUMB_TIP_TO_IP_CLOSE]
averages_THUMB_TIP_TO_IP_CLOSE_T = [round(sum(row) / len(row)) for row in sums_THUMB_TIP_TO_IP_CLOSE_T]
# 그래프 그리기
plt.plot(averages_THUMB_TIP_TO_IP_CLOSE_T, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_TIP_TO_IP_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 25
#      21 sums_THUMB_TIP_TO_IP_CLOSE_T = [sum(column) for column in zip(*THUMB_TIP_TO_IP_CLOSE_T)]
#      23 # 합을 평균으로 변환하기 (정수형으로 반올림)
#      24 # averages_THUMB_TIP_TO_IP_CLOSE = [round(sum_value / len(THUMB_TIP_TO_IP_CLOSE[0])) for sum_value in sums_THUMB_TIP_TO_IP_CLOSE]
# ---> 25 averages_THUMB_TIP_TO_IP_CLOSE_T = [round(sum(row) / len(row)) for row in sums_THUMB_TIP_TO_IP_CLOSE_T]
#      26 # 그래프 그리기
#      27 plt.plot(averages_THUMB_TIP_TO_IP_CLOSE_T, marker='o', linestyle='-')
#
# Cell In[21], line 25, in <listcomp>(.0)
#      21 sums_THUMB_TIP_TO_IP_CLOSE_T = [sum(column) for column in zip(*THUMB_TIP_TO_IP_CLOSE_T)]
#      23 # 합을 평균으로 변환하기 (정수형으로 반올림)
#      24 # averages_THUMB_TIP_TO_IP_CLOSE = [round(sum_value / len(THUMB_TIP_TO_IP_CLOSE[0])) for sum_value in sums_THUMB_TIP_TO_IP_CLOSE]
# ...
