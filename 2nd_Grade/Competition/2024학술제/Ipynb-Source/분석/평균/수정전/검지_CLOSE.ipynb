# %%
#1
import matplotlib.pyplot as plt

# 데이터
INDEX_TIP_TO_DIP_CLOSE = [
[102, 103, 104, 114, 160, 91, 88, 80, 82, 63, 58],

[101, 102, 100, 103, 114, 89, 73, 67, 69, 70, 70],

[103, 101, 101, 99, 94, 96, 90, 88, 76, 69, 72],

[104, 100, 98, 94, 87, 93, 95, 84, 75, 93, 79],

[106, 106, 102, 102, 112, 88, 76, 63, 59, 72, 68],

[102, 102, 100, 102, 89, 84, 52, 51, 71, 71, 69],

[103, 101, 123, 42, 58, 55, 37, 55, 62, 79, 67],

[104, 103, 102, 102, 102, 101, 104, 95, 88, 82, 75],

[100, 101, 99, 99, 103, 108, 94, 92, 89, 92, 81],

 [100, 101, 104, 108, 117, 85, 80, 68, 63, 67, 62]
]

# 각 열의 합을 구하기
sums_INDEX_TIP_TO_DIP_CLOSE = [sum(column) for column in zip(*INDEX_TIP_TO_DIP_CLOSE)]
averages_INDEX_TIP_TO_DIP_CLOSE = [round(sum(row) / len(row)) for row in INDEX_TIP_TO_DIP_CLOSE]
# 그래프 그리기
plt.plot(averages_INDEX_TIP_TO_DIP_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of INDEX_TIP_TO_DIP_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#2
import matplotlib.pyplot as plt

# 데이터
THUMB_DIP_TO_PIP_CLOSE = [
    [104, 104, 105, 105, 113, 118, 106, 93, 88, 84, 82],

    [104, 104, 103, 104, 98, 110, 88, 84, 82, 81, 81],

    [105, 103, 103, 101, 95, 94, 83, 93, 90, 84, 81],

    [105, 102, 100, 97, 93, 84, 89, 91, 87, 87, 83],

    [108, 108, 105, 103, 100, 98, 86, 80, 79, 74, 69],

    [104, 104, 102, 100, 94, 92, 78, 76, 81, 73, 69],

    [105, 103, 98, 77, 78, 80, 79, 81, 83, 74, 74],

    [106, 106, 105, 104, 104, 102, 101, 107, 108, 88, 86],

    [102, 103, 101, 100, 100, 96, 103, 105, 93, 91, 81],

     [103, 103, 105, 108, 110, 102, 89, 86, 85, 81, 68]
]

# 각 열의 합을 구하기
sums_THUMB_DIP_TO_PIP_CLOSE = [sum(column) for column in zip(*THUMB_DIP_TO_PIP_CLOSE)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
# averages_THUMB_DIP_TO_PIP_CLOSE = [round(sum_value / len(THUMB_DIP_TO_PIP_CLOSE[0])) for sum_value in sums_THUMB_DIP_TO_PIP_CLOSE]
averages_THUMB_DIP_TO_PIP_CLOSE = [round(sum(row) / len(row)) for row in THUMB_DIP_TO_PIP_CLOSE]

# 그래프 그리기
plt.plot(averages_THUMB_DIP_TO_PIP_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_DIP_TO_PIP_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#3
import matplotlib.pyplot as plt

# 데이터
THUMB_PIP_TO_MCP_CLOSE = [
    [103, 102, 101, 96, 93, 90, 94, 97, 93, 102, 104],

    [104, 104, 102, 99, 92, 92, 100, 103, 102, 98, 99],

    [104, 104, 103, 101, 96, 93, 89, 90, 94, 101, 100],

    [105, 103, 101, 99, 95, 85, 85, 92, 93, 84, 87],

    [109, 109, 106, 100, 97, 93, 98, 103, 109, 103, 106],

    [105, 103, 101, 96, 92, 95, 114, 110, 99, 102, 102],

    [104, 104, 89, 111, 112, 104, 115, 110, 104, 92, 100],

    [106, 108, 107, 104, 104, 100, 96, 91, 94, 94, 94],

    [103, 103, 101, 99, 94, 93, 92, 88, 88, 84, 91],

     [106, 106, 106, 105, 100, 93, 100, 103, 105, 104, 102]
]

# 각 열의 합을 구하기
sums_THUMB_PIP_TO_MCP_CLOSE = [sum(column) for column in zip(*THUMB_PIP_TO_MCP_CLOSE)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
# averages_THUMB_PIP_TO_MCP_CLOSE = [round(sum_value / len(THUMB_PIP_TO_MCP_CLOSE[0])) for sum_value in sums_THUMB_PIP_TO_MCP_CLOSE]
averages_THUMB_PIP_TO_MCP_CLOSE = [round(sum(row) / len(row)) for row in THUMB_PIP_TO_MCP_CLOSE]

# 그래프 그리기
plt.plot(averages_THUMB_PIP_TO_MCP_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_PIP_TO_MCP_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#4
import matplotlib.pyplot as plt

# 데이터
THUMB_MCP_TO_WRIST_CLOSE = [
[106, 105, 105, 107, 107, 106, 109, 110, 110, 111, 112],

[107, 107, 107, 106, 107, 110, 110, 112, 114, 115, 114],

[104, 105, 105, 105, 106, 105, 106, 106, 106, 113, 115],

[104, 105, 105, 105, 105, 104, 106, 103, 107, 112, 114],

[111, 110, 111, 111, 109, 111, 111, 116, 117, 122, 122],

[107, 107, 108, 107, 107, 107, 113, 116, 117, 120, 120],

[106, 106, 106, 110, 111, 112, 110, 113, 114, 118, 117],

[111, 111, 110, 109, 110, 109, 110, 110, 110, 112, 114],

[106, 105, 105, 105, 107, 107, 108, 106, 109, 110, 113],

 [107, 109, 110, 110, 111, 111, 110, 111, 112, 115, 121]
]

# 각 열의 합을 구하기
sums_THUMB_MCP_TO_WRIST_CLOSE = [sum(column) for column in zip(*THUMB_MCP_TO_WRIST_CLOSE)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
#averages_THUMB_MCP_TO_WRIST_CLOSE = [round(sum_value / len(THUMB_MCP_TO_WRIST_CLOSE[0])) for sum_value in sums_THUMB_MCP_TO_WRIST_CLOSE]
averages_THUMB_MCP_TO_WRIST_CLOSE = [round(sum(row) / len(row)) for row in THUMB_MCP_TO_WRIST_CLOSE]
# 그래프 그리기
plt.plot(averages_THUMB_MCP_TO_WRIST_CLOSE, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_MCP_TO_WRIST_CLOSE')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

averages = [round(sum(row) / len(row)) for row in THUMB_MCP_TO_WRIST_CLOSE]

print(averages)
# Out:
# [108, 110, 107, 106, 114, 112, 111, 111, 107, 112]
