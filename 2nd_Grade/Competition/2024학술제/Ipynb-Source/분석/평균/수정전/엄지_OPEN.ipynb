# %%
#1
import matplotlib.pyplot as plt

# 데이터
THUMB_TIP_TO_IP_OPEN = [
[121, 121, 120, 121, 120, 120, 120, 121, 121, 120, 120],
[122, 123, 122, 126, 122, 122, 123, 122, 123, 122, 122],
[122, 124, 122, 123, 123, 122, 122, 121, 122, 123, 121],
[119, 119, 117, 118, 117, 114, 114, 115, 117, 116, 116],
[118, 114, 118, 117, 114, 115, 114, 115, 116, 116, 116],
[115, 116, 117, 117, 115, 115, 116, 117, 116, 116, 118],
[123, 120, 118, 118, 119, 116, 115, 116, 115, 115, 116],
[116, 124, 125, 123, 119, 119, 120, 119, 117, 118, 117],
[113, 115, 116, 113, 116, 118, 118, 118, 117, 116, 117],
 [117, 117, 115, 114, 115, 115, 114, 114, 114, 113, 122]
]

# 각 열의 합을 구하기
sums_THUMB_TIP_TO_IP_OPEN = [sum(column) for column in zip(*THUMB_TIP_TO_IP_OPEN)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
#averages_THUMB_TIP_TO_IP_OPEN = [round(sum_value / len(THUMB_TIP_TO_IP_OPEN[0])) for sum_value in sums_THUMB_TIP_TO_IP_OPEN]
averages_THUMB_TIP_TO_IP_OPEN = [round(sum(row) / len(row)) for row in THUMB_TIP_TO_IP_OPEN]
# 그래프 그리기
plt.plot(averages_THUMB_TIP_TO_IP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_TIP_TO_IP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#2
import matplotlib.pyplot as plt

# 데이터
THUMB_IP_TO_MCP_OPEN = [
[114, 112, 111, 112, 112, 113, 111, 113, 114, 115, 115],

[115, 116, 115, 116, 115, 115, 114, 114, 115, 115, 114],

[114, 115, 116, 115, 114, 115, 114, 115, 114, 114, 114],

[112, 111, 110, 111, 109, 107, 106, 108, 109, 109, 110],

[111, 110, 109, 108, 107, 107, 106, 108, 108, 107, 107],

[106, 108, 107, 107, 107, 108, 108, 108, 108, 108, 110],

[118, 115, 114, 113, 114, 113, 113, 112, 113, 112, 112],

[113, 119, 114, 113, 112, 112, 112, 111, 111, 111, 111],

[110, 110, 109, 110, 109, 109, 109, 109, 108, 109, 109],

 [109, 109, 107, 107, 107, 106, 106, 106, 105, 107, 116]
]

# 각 열의 합을 구하기
sums_THUMB_IP_TO_MCP_OPEN = [sum(column) for column in zip(*THUMB_TIP_TO_IP_OPEN)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
#averages_THUMB_TIP_TO_IP_OPEN = [round(sum_value / len(THUMB_TIP_TO_IP_OPEN[0])) for sum_value in sums_THUMB_IP_TO_MCP_OPEN]
averages_THUMB_TIP_TO_IP_OPEN = [round(sum(row) / len(row)) for row in THUMB_IP_TO_MCP_OPEN]
# 그래프 그리기
plt.plot(averages_THUMB_TIP_TO_IP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_TIP_TO_IP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#3
import matplotlib.pyplot as plt

# 데이터
THUMB_MCP_TO_CMC_OPEN = [
    [125, 122, 122, 124, 124, 124, 123, 123, 125, 125, 125],
[124, 126, 126, 124, 125, 124, 122, 123, 125, 124, 123],
[124, 125, 125, 124, 124, 126, 125, 126, 124, 123, 125],
[124, 123, 123, 122, 122, 120, 120, 121, 124, 124, 124],
[123, 123, 122, 122, 120, 119, 119, 120, 120, 120, 119],
[119, 119, 118, 119, 119, 121, 120, 120, 121, 120, 122],
[127, 127, 128, 127, 128, 127, 126, 124, 125, 125, 124],
[125, 130, 124, 123, 124, 125, 123, 123, 123, 121, 122],
[123, 121, 120, 122, 120, 120, 121, 120, 120, 120, 121],
 [120, 120, 118, 118, 118, 118, 117, 118, 116, 118, 122]
]

# 각 열의 합을 구하기
sums_THUMB_MCP_TO_CMC_OPEN = [sum(column) for column in zip(*THUMB_MCP_TO_CMC_OPEN)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
averages_THUMB_MCP_TO_CMC_OPEN = [round(sum(row) / len(row)) for row in THUMB_MCP_TO_CMC_OPEN]
# 그래프 그리기
plt.plot(averages_THUMB_MCP_TO_CMC_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_MCP_TO_CMC_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#4
import matplotlib.pyplot as plt

# 데이터
THUMB_CMC_TO_WRIST_OPEN = [
[146, 145, 144, 147, 147, 145, 144, 146, 147, 149, 148],
[148, 149, 150, 147, 148, 146, 145, 145, 148, 147, 146],
[146, 149, 148, 147, 146, 148, 148, 148, 147, 146, 144],
[145, 145, 144, 144, 145, 141, 139, 145, 149, 146, 146],
[147, 143, 148, 147, 141, 141, 138, 138, 137, 138, 139],
[138, 139, 137, 140, 139, 141, 141, 140, 139, 142, 140],
[145, 148, 148, 146, 151, 148, 145, 144, 144, 144, 145],
[145, 152, 149, 147, 146, 146, 146, 145, 143, 143, 144],
[141, 141, 142, 141, 141, 142, 142, 140, 142, 141, 141],
 [139, 140, 140, 139, 141, 140, 141, 142, 143, 145, 142]
]

# 각 열의 합을 구하기
sums_THUMB_CMC_TO_WRIST_OPEN = [sum(column) for column in zip(*THUMB_CMC_TO_WRIST_OPEN)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
averages_THUMB_CMC_TO_WRIST_OPEN = [round(sum(row) / len(row)) for row in THUMB_CMC_TO_WRIST_OPEN]
# 그래프 그리기
plt.plot(averages_THUMB_CMC_TO_WRIST_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_CMC_TO_WRIST_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()
