# %%
#1
import matplotlib.pyplot as plt

# 데이터
INDEX_TIP_TO_DIP_OPEN = [
[107, 108, 107, 107, 106, 107, 105, 107, 106, 106, 106],

[106, 100, 101, 100, 101, 102, 101, 101, 100, 101, 101],

[100, 101, 101, 102, 104, 102, 101, 102, 102, 102, 101],

[103, 102, 103, 103, 101, 100, 101, 102, 102, 102, 100],

[101, 102, 101, 101, 100, 98, 99, 99, 98, 99, 99],

[100, 98, 98, 100, 99, 103, 101, 100, 101, 104, 104],

[103, 104, 105, 104, 104, 104, 104, 104, 110, 109, 111],

[107, 107, 108, 106, 106, 108, 106, 105, 105, 105, 104],

[103, 102, 102, 105, 103, 103, 103, 103, 104, 101, 100],

 [111, 110, 109, 110, 110, 110, 108, 109, 111, 107, 107]
]

# 각 열의 합을 구하기
sums_INDEX_TIP_TO_DIP_OPEN = [sum(column) for column in zip(*INDEX_TIP_TO_DIP_OPEN)]
averages_INDEX_TIP_TO_DIP_OPEN = [round(sum(row) / len(row)) for row in INDEX_TIP_TO_DIP_OPEN]
# 그래프 그리기
plt.plot(averages_INDEX_TIP_TO_DIP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of INDEX_TIP_TO_DIP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#2
import matplotlib.pyplot as plt

# 데이터
THUMB_DIP_TO_PIP_OPEN = [
    [108, 110, 110, 109, 109, 110, 108, 110, 109, 109, 108],

    [109, 103, 104, 103, 104, 104, 104, 104, 103, 104, 104],

    [104, 104, 104, 104, 106, 104, 104, 105, 105, 105, 105],

    [105, 105, 105, 105, 103, 102, 102, 104, 104, 104, 103],

    [103, 104, 103, 104, 103, 100, 101, 101, 100, 101, 101],

    [102, 100, 101, 102, 101, 105, 102, 102, 102, 105, 105],

    [104, 105, 105, 105, 105, 105, 105, 105, 111, 110, 113],

    [108, 109, 110, 109, 108, 109, 108, 107, 107, 107, 106],

    [105, 104, 104, 106, 105, 105, 104, 105, 105, 103, 102],

     [112, 111, 110, 111, 111, 111, 110, 111, 112, 109, 109]
]

# 각 열의 합을 구하기
sums_THUMB_DIP_TO_PIP_OPEN = [sum(column) for column in zip(*THUMB_DIP_TO_PIP_OPEN)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
# averages_THUMB_DIP_TO_PIP_OPEN = [round(sum_value / len(THUMB_DIP_TO_PIP_OPEN[0])) for sum_value in sums_THUMB_DIP_TO_PIP_OPEN]
averages_THUMB_DIP_TO_PIP_OPEN = [round(sum(row) / len(row)) for row in THUMB_DIP_TO_PIP_OPEN]

# 그래프 그리기
plt.plot(averages_THUMB_DIP_TO_PIP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_DIP_TO_PIP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#3
import matplotlib.pyplot as plt

# 데이터
THUMB_PIP_TO_MCP_OPEN = [
[109, 111, 111, 108, 110, 109, 109, 109, 110, 109, 109],

[109, 106, 106, 105, 106, 106, 106, 105, 106, 106, 107],

[107, 106, 106, 106, 106, 106, 106, 106, 107, 106, 107],

[107, 107, 107, 107, 105, 104, 104, 106, 107, 106, 106],

[105, 106, 106, 106, 104, 102, 102, 102, 101, 102, 102],

[102, 101, 101, 102, 103, 105, 103, 105, 103, 106, 107],

[106, 105, 105, 107, 106, 107, 106, 105, 112, 112, 112],

[109, 109, 110, 109, 109, 109, 109, 108, 108, 107, 106],

[106, 106, 106, 106, 106, 106, 106, 106, 106, 104, 104],

 [112, 113, 112, 111, 111, 112, 111, 110, 111, 110, 110]
]

# 각 열의 합을 구하기
sums_THUMB_PIP_TO_MCP_OPEN = [sum(column) for column in zip(*THUMB_PIP_TO_MCP_OPEN)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
# averages_THUMB_PIP_TO_MCP_OPEN = [round(sum_value / len(THUMB_PIP_TO_MCP_OPEN[0])) for sum_value in sums_THUMB_PIP_TO_MCP_OPEN]
averages_THUMB_PIP_TO_MCP_OPEN = [round(sum(row) / len(row)) for row in THUMB_PIP_TO_MCP_OPEN]

# 그래프 그리기
plt.plot(averages_THUMB_PIP_TO_MCP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_PIP_TO_MCP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#4
import matplotlib.pyplot as plt

# 데이터
THUMB_MCP_TO_WRIST_OPEN = [
[115, 115, 115, 110, 110, 110, 112, 111, 111, 111, 112],

[112, 110, 110, 111, 111, 110, 108, 110, 111, 110, 109],

[110, 111, 112, 112, 111, 112, 112, 112, 113, 111, 112],

[111, 112, 112, 112, 111, 112, 114, 112, 112, 111, 113],

[113, 112, 111, 111, 112, 111, 109, 110, 112, 111, 111],

[109, 112, 112, 110, 110, 110, 109, 108, 108, 112, 110],

[110, 110, 110, 111, 110, 110, 110, 111, 109, 109, 109],

[110, 109, 108, 109, 110, 110, 109, 109, 109, 109, 111],

[110, 111, 110, 111, 110, 111, 110, 110, 111, 111, 110],

 [110, 110, 109, 109, 111, 110, 110, 109, 109, 110, 109]
]

# 각 열의 합을 구하기
sums_THUMB_MCP_TO_WRIST_OPEN = [sum(column) for column in zip(*THUMB_MCP_TO_WRIST_OPEN)]

# 합을 평균으로 변환하기 (정수형으로 반올림)
#averages_THUMB_MCP_TO_WRIST_OPEN = [round(sum_value / len(THUMB_MCP_TO_WRIST_OPEN[0])) for sum_value in sums_THUMB_MCP_TO_WRIST_OPEN]
averages_THUMB_MCP_TO_WRIST_OPEN = [round(sum(row) / len(row)) for row in THUMB_MCP_TO_WRIST_OPEN]
# 그래프 그리기
plt.plot(averages_THUMB_MCP_TO_WRIST_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of THUMB_MCP_TO_WRIST_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

averages = [round(sum(row) / len(row)) for row in THUMB_MCP_TO_WRIST_OPEN]

print(averages)
# Out:
# [112, 110, 112, 112, 111, 110, 110, 109, 110, 110]
