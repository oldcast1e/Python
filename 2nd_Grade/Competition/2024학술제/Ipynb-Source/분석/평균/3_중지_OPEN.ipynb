# %% [markdown]
# ### 점검 완료

# %%
#1
import matplotlib.pyplot as plt

# 데이터
MIDDLE_DIP_TO_TIP_OPEN = [
    [85, 84, 85, 86, 86, 83, 86, 85, 86, 89],
    [86, 84, 85, 87, 86, 86, 86, 85, 86, 88],
    [86, 85, 86, 87, 86, 87, 87, 85, 86, 88],
    [85, 85, 86, 87, 86, 87, 86, 85, 85, 88],
    [85, 85, 86, 87, 86, 87, 86, 85, 85, 88],
    [86, 85, 86, 87, 86, 88, 86, 84, 85, 88],
    [85, 85, 86, 87, 87, 88, 86, 84, 86, 88],
    [86, 85, 86, 87, 86, 88, 86, 84, 86, 89],
    [86, 85, 86, 87, 85, 87, 86, 84, 85, 89],
    [86, 84, 86, 87, 87, 87, 86, 85, 85, 88]
]

# 각 열의 합을 구하기
sums_MIDDLE_DIP_TO_TIP_OPEN = [sum(column) for column in zip(*MIDDLE_DIP_TO_TIP_OPEN)]
averages_MIDDLE_DIP_TO_TIP_OPEN = [round(sum(row) / len(row)) for row in MIDDLE_DIP_TO_TIP_OPEN]
# 그래프 그리기
plt.plot(averages_MIDDLE_DIP_TO_TIP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of MIDDLE_DIP_TO_TIP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#2
import matplotlib.pyplot as plt

# 데이터
MIDDLE_PIP_TO_DIP_OPEN = [
    [86, 85, 87, 86, 83, 84, 85, 86, 88, 85],
    [86, 88, 87, 87, 86, 87, 85, 87, 88, 85],
    [87, 87, 88, 87, 89, 87, 86, 87, 89, 86],
    [87, 87, 87, 87, 87, 87, 86, 87, 88, 86],
    [88, 87, 88, 86, 88, 86, 86, 88, 88, 86],
    [87, 87, 88, 87, 87, 86, 86, 88, 89, 86],
    [87, 87, 88, 87, 87, 86, 87, 87, 89, 87],
    [88, 88, 88, 87, 87, 86, 86, 87, 88, 87],
    [88, 88, 88, 87, 87, 86, 86, 87, 88, 86],
    [88, 88, 88, 87, 87, 85, 86, 87, 88, 86]
]

# 각 열의 합을 구하기
sums_MIDDLE_PIP_TO_DIP_OPEN = [sum(column) for column in zip(*MIDDLE_PIP_TO_DIP_OPEN)]
averages_MIDDLE_PIP_TO_DIP_OPEN = [round(sum(row) / len(row)) for row in MIDDLE_PIP_TO_DIP_OPEN]
# 그래프 그리기
plt.plot(averages_MIDDLE_PIP_TO_DIP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of MIDDLE_PIP_TO_DIP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#3
import matplotlib.pyplot as plt

# 데이터
MIDDLE_MCP_TO_PIP_OPEN = [
[88, 89, 90, 90, 91, 90, 89, 90, 88, 87], 
 [88, 89, 90, 90, 91, 91, 90, 90, 88, 87], 
 [88, 90, 90, 90, 91, 90, 90, 91, 89, 87], 
 [88, 89, 90, 90, 91, 90, 90, 90, 90, 87], 
 [87, 90, 90, 90, 91, 91, 91, 90, 89, 87], 
 [87, 90, 90, 90, 91, 91, 90, 90, 89, 88], 
 [88, 90, 90, 90, 91, 90, 90, 89, 89, 88], 
 [89, 90, 90, 90, 91, 90, 90, 89, 89, 87], 
 [89, 90, 90, 90, 90, 90, 90, 89, 89, 87], 
 [88, 90, 90, 90, 90, 90, 90, 88, 89, 88]
]

# 각 열의 합을 구하기
sums_MIDDLE_MCP_TO_PIP_OPEN = [sum(column) for column in zip(*MIDDLE_MCP_TO_PIP_OPEN)]
averages_MIDDLE_MCP_TO_PIP_OPEN = [round(sum(row) / len(row)) for row in MIDDLE_MCP_TO_PIP_OPEN]
# 그래프 그리기
plt.plot(averages_MIDDLE_MCP_TO_PIP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of MIDDLE_MCP_TO_PIP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()

# %%
#4
import matplotlib.pyplot as plt

# 데이터
MIDDLE_WRIST_TO_MCP_OPEN = [
    [90, 91, 91, 91, 91, 91, 91, 91, 91, 92],
    [91, 91, 91, 90, 92, 92, 91, 91, 91, 92],
    [91, 91, 91, 90, 92, 91, 91, 91, 91, 92],
    [91, 91, 91, 91, 92, 92, 91, 90, 91, 92],
    [91, 91, 91, 90, 92, 92, 88, 90, 91, 92],
    [92, 91, 91, 89, 93, 91, 91, 90, 91, 92],
    [91, 92, 91, 90, 93, 91, 91, 90, 92, 92],
    [92, 93, 91, 91, 93, 92, 91, 90, 91, 92],
    [92, 92, 91, 92, 93, 92, 91, 90, 92, 92],
    [92, 92, 91, 91, 93, 92, 91, 90, 91, 92]
]

# 각 열의 합을 구하기
sums_MIDDLE_WRIST_TO_MCP_OPEN = [sum(column) for column in zip(*MIDDLE_WRIST_TO_MCP_OPEN)]
averages_MIDDLE_WRIST_TO_MCP_OPEN = [round(sum(row) / len(row)) for row in MIDDLE_WRIST_TO_MCP_OPEN]
# 그래프 그리기
plt.plot(averages_MIDDLE_WRIST_TO_MCP_OPEN, marker='o', linestyle='-')
plt.title('TAverage graph of MIDDLE_WRIST_TO_MCP_OPEN')
plt.xlabel('column')
plt.ylabel('Average')
plt.ylim(0, 180)  # 세로 구간 설정
plt.grid(True)
plt.show()
